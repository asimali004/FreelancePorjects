# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

# %%
df3=pd.read_csv("https://raw.githubusercontent.com/fh-aachen-semesterprojekt/Staedteregion-Aachen/main/Pressemitteilung-Entwicklung-2021.csv")

# %%
df3
# Out:
#           Tag     Ort  Aktive_Faelle  Gesamt  Sieben_Tage_Inzidenz
# 0  2021-01-15  Aachen            955   15745                    96
# 1  2021-01-14  Aachen           1077   15657                   113
# 2  2021-01-13  Aachen           1028   15548                   129
# 3  2021-01-12  Aachen           1114   15469                   134
# 4  2021-01-11  Aachen           1366   15460                   133
# 5  2021-01-08  Aachen           1413   15211                   116
# 6  2021-01-07  Aachen           1272   15028                   114
# 7  2021-01-06  Aachen           1319   14832                   105
# 8  2021-01-05  Aachen           1473   14723                   116
# 9  2021-01-04  Aachen           1581   14721                   127

# %%
df3=df3[::-1]
df3.index=[i for i in range(0,len(df3))]

# %%
plt.figure(figsize=(16,6))
plt.plot(df3["Tag"],df3.iloc[:,2],lw=2)
plt.title("Aktive_Faelle",fontsize=25,color="b")
plt.xlabel("Date")
style.use("classic")
plt.grid(color="g",ls="-",lw=0.5)

# %%
plt.figure(figsize=(16,6))
plt.plot(df3["Tag"],df3.iloc[:,3],lw=2)
plt.title("Gesamt",fontsize=25,color="r")
plt.xlabel("Date")
style.use("classic")
plt.grid(color="c",ls="-",lw=0.5)

# %%
plt.figure(figsize=(16,6))
plt.plot(df3["Tag"],df3.iloc[:,4],lw=2,)
plt.title("Sieben_Tage_Inzidenz",fontsize=25,color="m")
plt.xlabel("Date")
style.use("classic")
plt.grid(color="y",ls="-",lw=0.5)
